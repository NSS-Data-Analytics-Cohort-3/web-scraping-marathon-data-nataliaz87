# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ###Overall = []
# Bib = []
# Name = []
# Time = []
# df=pd.DataFrame()

# %%
URL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2016-Results"

# %%
page = requests.post(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
results = soup.find(id = 'main-container')

# %%
print(results.prettify())
# Out:
# <div id="main-container">
#  <header class="header-static">
#   <nav class="navbar navbar-default navbar-static" id="mainNavbar">
#    <div class="container">
#     <div class="row">
#      <div class="nav-wrapper">
#       <div class="navbar-right col-sm-12 col-md-2 col-lg-2 clearfix">
#        <div class="navbar-activity event-navbar-activity">
#         <ul class="nav navbar-nav">
#          <li class="dropdown">
#           <a class="btn dropdown-toggle" data-toggle="dropdown" href="#">
#            <i class="fa fa-globe">
#            </i>
#           </a>
#           <ul class="dropdown-menu">
#            <li class="">
#             <a href="https://www.runrocknroll.com:443/it/events/nashville/the races/half marathon/2016 results/" onclick="return SwitchToLanguage('it', 'en', 'https://www.runrocknroll.com:443/it/events/nashville/the races/half marathon/2016 results/')">
#              italiano
#             </a>
#            </li>
#            <li class="">
# ...

# %%
job_elems = results.find_all('section', class_='section-full')

# %%
for job_elem in job_elems:
    print(job_elem, end='\n'*2)
# Out:
# <section class="section section-full">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <div class="row race-search-res-container">
# <div class="race-search-res-div-main col-xs-12">
# <h2><br/><small>Saturday, April 30, 2016</small></h2>
# <div class="race-search-main col-xs-12">
# <div class="race-search-top10-div">
# <table class="table table-responsive table-bordered">
# <tr>
# <th class="table-place">Overall</th>
# <th class="table-place">Bib</th>
# <th class="table-name">Name</th>
# <th class="table-time">Time</th>
# </tr>
# <tr>
# <td>1</td>
# <td>201</td>
# <td><a href="/en/Events/Nashville/The-Races/Half-Marathon/2016-Results/Athlete?id=201">Roosevelt Cook</a></td>
# <td>01:11:15</td>
# </tr>
# <tr>
# <td>2</td>
# <td>204</td>
# <td><a href="/en/Events/Nashville/The-Races/Half-Marathon/2016-Results/Athlete?id=204">Bill Martin</a></td>
# <td>01:11:50</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1623</td>
# ...

# %%
for job_elem in job_elems:
    # Each job_elem is a new BeautifulSoup object.
    # You can use the same methods on it as you did before.
    title_elem = job_elem.find('th', class_='table-place')
    title_elem2 = job_elem.find('th', class_='table-place')
    company_elem = job_elem.find('th', class_='table-name')
    location_elem = job_elem.find('th', class_='table-time')
    print(title_elem)
    print(company_elem)
    print(location_elem)
    print()
# Out:
# <th class="table-place">Overall</th>
# <th class="table-name">Name</th>
# <th class="table-time">Time</th>
#
# None
# None
# None

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")
m_2016 = soup.find_all("div",{"class": "race-search-main"})

len(m_2016)
# Out:
# 1
